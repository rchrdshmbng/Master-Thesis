# %%
# Import packages in alphabetical order
import pandas as pd
import tiktoken
import os
import openai
import duckdb
import owlready2
import sklearn

import gensim
import matplotlib.pyplot as plt
import nltk
import pickle
import re
import spacy
import string

# Import packages in alphabetical order to avoid duplicates
from gensim.models import Word2Vec
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
from sklearn.cluster import KMeans
from transformers import BertModel, BertTokenizer
from wordcloud import WordCloud

# %%
#Load duckdb
con = duckdb.connect('/home/roland/Projects/timothy/Master-Thesis/isrecon.duckdb', read_only = True)

# %%
#Load sentences from duckdb
sentences_df = con.execute("""
                        SELECT article_id, sentence_id, sentence
                        FROM sentences""").fetchdf()
sentences_df.head()
# Out:
#    article_id sentence_id                                           sentence
# 0           1      1_2_21  Examining interdependence between product user...
# 1           1     1_22_48  Abstract. Firm - sponsored online user communi...
# 2           1     1_48_65  Product users and host firm employees comprise...
# 3           1     1_65_95  The online user community provides a forum whe...
# 4           1    1_95_125  Extant research on online user communities has...

# %%
# Group by 'article_id' and concatenate 'sentence'
grouped_sentences = sentences_df.groupby('article_id')['sentence'].apply(' '.join).reset_index()

# %%
#Preview grouped sentences
grouped_sentences.head()
# Out:
#    article_id                                           sentence
# 0           1  Examining interdependence between product user...
# 1           2  Information management as an enabler of knowle...
# 2           3  Action Research and Critical Rationalisationis...
# 3           4  Integration of Supply Chain Execution in B2B M...
# 4           5  Association for Information Systems AIS Electr...

# %%
#Preview the whole first row
print(grouped_sentences.iloc[0]['sentence'])
# Out:
# Examining interdependence between product users users and employees in online user communities : The role of employee - generated content Abstract. Firm - sponsored online user communities have become product innovation and support hubs of strategic importance to firms . Product users and host firm employees comprise the participants of firm - sponsored online user communities . The online user community provides a forum wherein the product users users and firm employees discuss questions , problems or issues resulting from the use of host firms ' products . Extant research on online user communities has largely focused on either product users users or employees and has examined the various dynamics that ensue from each entity 's community participation . This paper seeks to investigate the interdependence between the two entities in the communities and , in particular , how product users users ' reading of employee - generated content influences subsequent knowledge contribution by product users users as well as employees . Analyzing data from an online user community over a two - year period , our study shows that employees whose content is read by product users users generate additional content and product users users who read employee content themselves contribute more knowledge to the community . Thus , the reading of content is not entirely a passive , individual action that only affects the reader . On the contrary , reading sparks additional knowledge contribution by the reader and having readers sparks additional knowledge contribution by the original source of the content , thereby creating a sustainable online user community . Introduction Firm - hosted online user communities ( hereinafter OUC ) refer to firm - sponsored initiatives aiming to help a firm respond to the myriad of questions coming from external product users users ( henceforth , product users users ) while leveraging their knowledge and expertise for existing product support . OUC have the potential to become a real - time , constantly updated product knowledge repository to serve existing product support( Nambisan , 2002 ) . In addition to potentially improving customer loyalty , product and brand perceptions , and lifetime customer value , OUC may also help host - firms cultivate a more customer - centered culture by incorporating customer feedback into decision - making at the executive level( Leidner , 2009 ; , 2002 ) . As a consequence , OUC are of strategic importance to firms . Firms across industries , especially in the high - tech sector , have implemented OUC as a means to support their business strategy( Yan et al . , 2018 ) . SAP , for example , has implemented its OUC ( SAP Community Network ) as part of its platform strategy ( seeHuang et al . , 2018 ) . Examples of other well - known OUC include Salesforce.com 's Trailblazer community , BMC 's Products community and Cisco 's Technology & Support community . A key issue facing firms that seek to capitalize on the strategic value of OUC is ensuring active user participation . A large body of extant OUC research has therefore examined the factors that motivate product users users to participate in and contribute to the communities ( see Table A1 in Appendix ) . Other studies have focused on the role of internal employees ( henceforth , employees ) of the host firms who also participate in OUC . These employees help manage various community challenges including understanding product support requests and identifying best answers( Di Gangi et al . , 2010 ) . Such engagement helps meet product users users ' needs and expectations of product support . As a result , it contributes to product users users ' satisfaction with the community as well as with the host firm( Nambisan , 2002 ) . The participation of employees thereby holds the potential to help sustain and realize value from the community( Nambisan and Baron , 2010 ) . While prior research provides valuable insights into why and how pro ...

# %%
#Import text processor
def text_processing(df, col):
    # Make sure to handle NaN values by converting them to an empty string
    temp_df = df[col].fillna('')
    # 1. Convert to lower case
    temp_df = temp_df.apply(lambda x: x.lower() if isinstance(x, str) else x)
    # 2. Remove punctuation
    temp_df = temp_df.apply(lambda x: re.sub('[^a-zA-Z]', ' ', x) if isinstance(x, str) else x)
    # 3. Remove special characters and digits
    temp_df = temp_df.apply(lambda x: re.sub("(\\d|\\W)+", " ", x) if isinstance(x, str) else x)
    # 4. Remove single-letter words
    temp_df = temp_df.apply(lambda x: re.sub(r"\b[a-zA-Z]\b", "", x) if isinstance(x, str) else x)
    # 5. Replace multiple spaces with a single space
    temp_df = temp_df.apply(lambda x: re.sub(r"\s+", " ", x) if isinstance(x, str) else x)
    return temp_df

# %%
#Process 'sentence' column
grouped_sentences["processed_sentence"] = text_processing(grouped_sentences,'sentence')

#Preview the new grouped_sentences dataframe
grouped_sentences.head()
# Out:
#    article_id                                           sentence  \
# 0           1  Examining interdependence between product user...
# 1           2  Information management as an enabler of knowle...
# 2           3  Action Research and Critical Rationalisationis...
# 3           4  Integration of Supply Chain Execution in B2B M...
# 4           5  Association for Information Systems AIS Electr...
#
#                                   processed_sentence
# 0  examining interdependence between product user...
# 1  information management as an enabler of knowle...
# 2  action research and critical rationalisationis...
# 3  integration of supply chain execution in marke...
# 4  association for information systems ais electr...

# %%
#Preview the whole first row of the processed sentence
print(grouped_sentences.iloc[0]['processed_sentence'])
# Out:
# examining interdependence between product users users and employees in online user communities the role of employee generated content abstract firm sponsored online user communities have become product innovation and support hubs of strategic importance to firms product users and host firm employees comprise the participants of firm sponsored online user communities the online user community provides forum wherein the product users users and firm employees discuss questions problems or issues resulting from the use of host firms products extant research on online user communities has largely focused on either product users users or employees and has examined the various dynamics that ensue from each entity community participation this paper seeks to investigate the interdependence between the two entities in the communities and in particular how product users users reading of employee generated content influences subsequent knowledge contribution by product users users as well as employees analyzing data from an online user community over two year period our study shows that employees whose content is read by product users users generate additional content and product users users who read employee content themselves contribute more knowledge to the community thus the reading of content is not entirely passive individual action that only affects the reader on the contrary reading sparks additional knowledge contribution by the reader and having readers sparks additional knowledge contribution by the original source of the content thereby creating sustainable online user community introduction firm hosted online user communities hereinafter ouc refer to firm sponsored initiatives aiming to help firm respond to the myriad of questions coming from external product users users henceforth product users users while leveraging their knowledge and expertise for existing product support ouc have the potential to become real time constantly updated product knowledge repository to serve existing product support nambisan in addition to potentially improving customer loyalty product and brand perceptions and lifetime customer value ouc may also help host firms cultivate more customer centered culture by incorporating customer feedback into decision making at the executive level leidner as consequence ouc are of strategic importance to firms firms across industries especially in the high tech sector have implemented ouc as means to support their business strategy yan et al sap for example has implemented its ouc sap community network as part of its platform strategy seehuang et al examples of other well known ouc include salesforce com trailblazer community bmc products community and cisco technology support community key issue facing firms that seek to capitalize on the strategic value of ouc is ensuring active user participation large body of extant ouc research has therefore examined the factors that motivate product users users to participate in and contribute to the communities see table in appendix other studies have focused on the role of internal employees henceforth employees of the host firms who also participate in ouc these employees help manage various community challenges including understanding product support requests and identifying best answers di gangi et al such engagement helps meet product users users needs and expectations of product support as result it contributes to product users users satisfaction with the community as well as with the host firm nambisan the participation of employees thereby holds the potential to help sustain and realize value from the community nambisan and baron while prior research provides valuable insights into why and how product users users or employees participate in and contribute to the community we know little about the interdependence between the two entities in ouc understanding user employee interdependence is important because the long term success of any ouc may be contingent upon ...

# %%
grouped_sentences.head()
# Out:
#    article_id                                           sentence  \
# 0           1  Examining interdependence between product user...
# 1           2  Information management as an enabler of knowle...
# 2           3  Action Research and Critical Rationalisationis...
# 3           4  Integration of Supply Chain Execution in B2B M...
# 4           5  Association for Information Systems AIS Electr...
#
#                                   processed_sentence
# 0  examining interdependence between product user...
# 1  information management as an enabler of knowle...
# 2  action research and critical rationalisationis...
# 3  integration of supply chain execution in marke...
# 4  association for information systems ais electr...

# %%
import pickle

# %%
#Save the grouped_sentences dataframe as pickle
with open('Datasets/grouped_sentences.pkl', 'wb') as f:
    pickle.dump(grouped_sentences, f)

# %%
#Check disk quota
os.system('quota -s')
# Out:
# Disk quotas for user roland (uid 1002):
#      Filesystem   space   quota   limit   grace   files   quota   limit   grace
#    /dev/nvme0n1    226G      0K    300G            815k       0       0
# 0

# %%
#Display biggest files in current quota
os.system('du -a /home/roland/Projects/richard | sort -n -r | head -n 10')
# Out:
# 4282496	/home/roland/Projects/richard
# 4282252	/home/roland/Projects/richard/grouped_sentences.pickle
# 144	/home/roland/Projects/richard/data_load.ipynb
# 88	/home/roland/Projects/richard/LLM_SOLAR-10.7B.ipynb
# 8	/home/roland/Projects/richard/data_processing.ipynb
# 0	/home/roland/Projects/richard/LLM_quantum-dpo-v0.1.ipynb
# 0

# %%
#Clear cache in current quota
os.system('rm -rf /home/roland/Projects/richard/*')
# Out:
# 0

# %%
#Check current memory usage
os.system('free -m')
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:        1546783       65278     1159084          71      322419     1473541
# Swap:          8191           0        8191
# 0

# %%
#Free some memory usage
os.system('sudo sysctl -w vm.drop_caches=3')
# Out:
# sudo: a terminal is required to read the password; either use the -S option to read from standard input or configure an askpass helper
# 256
